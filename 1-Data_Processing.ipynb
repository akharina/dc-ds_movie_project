# %% [markdown]
# # Movie Project - Data Processing Notebook
#
#
# ## Github repo:
# https://github.com/akharina/dc-ds_movie_project.git
#
#
# ## Data directory:
# * data/raw          : provided datasets
# * data/raw/kaggle   : data from [Kaggle](https://www.kaggle.com/rounakbanik/the-movies-dataset)
#
#
# ## Workflow:
# 1. Exploring datasets
# 2. Merging two datasets to work with
# 3. Going through every relevant column to clean and reformat data as necessary
# 4. Adding new columns as necessary
# 4. Remove unwanted columns from final dataset and save the file as a compressed csv file
#
# ## Final dataset : data/final/movie_dataset_df.csv.gz

# %%
#Importing all necessary tools

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yaml 

# %matplotlib inline

# %%
kaggle_movies = pd.read_csv('data/raw/kaggle/movies_metadata.csv.gz')
kaggle_movies.head()
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
df_crew = pd.read_csv('data/raw/kaggle/credits.csv.gz')
df_crew.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
#Merging main dataframe with crew dataframe 
df_crew['id'] = df_crew['id'].astype(str)
df = pd.merge(kaggle_movies, df_crew, how = 'left', on='id')
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    81.0
# 1  When siblings Judy and Peter discover an encha...  ...   104.0
# 2  A family wedding reignites the ancient feud be...  ...   101.0
# 3  Cheated on, mistreated and stepped on, the wom...  ...   127.0
# 4  Just when George Banks has recovered from his ...  ...   106.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average vote_count  \
# 0                    Toy Story  False           7.7     5415.0
# 1                      Jumanji  False           6.9     2413.0
# 2             Grumpier Old Men  False           6.5       92.0
# 3            Waiting to Exhale  False           6.1       34.0
# 4  Father of the Bride Part II  False           5.7      173.0
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'cast', 'crew'],
#       dtype='object')

# %%
#Renaming column names into shorter, more meaningful names
df = df.rename(columns={
    'belongs_to_collection':'collection',
    'spoken_languages':'languages',
    'release_date': 'date',
    'vote_average': 'vote_avg'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45542 entries, 0 to 45541
# Data columns (total 26 columns):
# adult                   45542 non-null object
# collection              4503 non-null object
# budget                  45542 non-null object
# genres                  45542 non-null object
# homepage                7795 non-null object
# id                      45542 non-null object
# imdb_id                 45525 non-null object
# original_language       45531 non-null object
# original_title          45542 non-null object
# overview                44588 non-null object
# popularity              45537 non-null object
# poster_path             45156 non-null object
# production_companies    45539 non-null object
# production_countries    45539 non-null object
# date                    45455 non-null object
# revenue                 45536 non-null float64
# runtime                 45279 non-null float64
# languages               45536 non-null object
# status                  45455 non-null object
# tagline                 20439 non-null object
# title                   45536 non-null object
# video                   45536 non-null object
# vote_avg                45536 non-null float64
# vote_count              45536 non-null float64
# cast                    45538 non-null object
# crew                    45538 non-null object
# dtypes: float64(4), object(22)
# memory usage: 9.4+ MB

# %%
#Dropping rows without imdb id (there are only 17 of them and all have 0 revenues)

not_in_imdb = df.loc[df['imdb_id'].isna() == True].index
df.drop(not_in_imdb, inplace = True)

# %% [markdown]
# ## Going column-by-column to check for null values and reshape into intended format if necessary

# %% [markdown]
# ### "adult" column

# %%
#Column 'adult'
df['adult'].isna().sum()

#Changing column 'adult' to boolean
df['adult'] = df['adult'].astype('bool')
df.adult.dtype
# Out:
# dtype('bool')

# %% [markdown]
# ### "date" column

# %%
#Changing null values in column 'date' into an impossible date
df['date'] = df['date'].fillna('1800-01-01')
df['date'].isnull().sum()
# Out:
# 0

# %%
#check for unusual values in 'date' columns: proper date should have 10
#characters 

df['date'].apply(len).value_counts()
# Out:
# 10    45522
# 2         2
# 1         1
# Name: date, dtype: int64

# %%
#Checking the index of the weird values above and removing those rows
weird_date = df['date'].loc[df['date'].apply(len) < 10]
df = df.drop(index=list(weird_date.index))

df['date'].apply(len).value_counts()
# Out:
# 10    45522
# Name: date, dtype: int64

# %%
#Changing column 'date' to datetime
df['date'] = pd.to_datetime(df['date'])

# %%
#Adding "WEEK", "MONTH", and "YEAR" columns

df['WEEK'] = df['date'].dt.week
df['MONTH'] = df['date'].dt.month_name()
df['YEAR'] = df['date'].dt.year

# %% [markdown]
# ### "languages" column

# %%
# df_null = df.loc[df['languages'].isna()]
# df = df.drop(index = list(df_null.index))

# %%
# #Parsing 'languages' column into a new list
# df['LANGUAGES'] = df['languages'].apply(lambda yaml_obj: [dict_obj['name'] for dict_obj in yaml.load(yaml_obj, Loader=yaml.FullLoader)])

# %% [markdown]
# ### "collection" column

# %%
#Filling null value in 'collection' column with an empty dictionary
# df['collection'].fillna("{'name':''}",inplace=True)

# %%
# yaml.load(df['collection'][12],Loader=yaml.FullLoader)['name']
# Out:
# 'Balto Collection'

# %%
#Parsing 'collection' column and get 'collection name', place values into a new column ['COLLECTION']
# df['COLLECTION'] = df['collection'].apply(lambda yaml_obj: yaml.load(yaml_obj, Loader=yaml.FullLoader)['name'])

# %% [markdown]
# ### "budget" column

# %%
#Changing type to int and making unit $million for readibility

df['budget'] = pd.to_numeric(df['budget'])
df['BUDGET_MIL'] = df['budget'] / 1000000

#Reassigning 0 values to a negative value for easy filtering
def budget_no_zero(value):
    if value > 1:
        return value
    else:
        return -1

df['BUDGET_MIL'] = df['BUDGET_MIL'].apply(budget_no_zero)

df['BUDGET_MIL'].describe()
# Out:
# count    45522.000000
# mean         3.369398
# std         17.625703
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max        380.000000
# Name: BUDGET_MIL, dtype: float64

# %%
df.loc[df['BUDGET_MIL']]
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#        adult                                         collection      budget  \
#  30.00  True                                                NaN         0.0
#  65.00  True  {'id': 124935, 'name': 'The Lawnmower Man Coll...         0.0
# -1.00    NaN                                                NaN         NaN
#  16.00  True                                                NaN  16500000.0
# -1.00    NaN                                                NaN         NaN
#  60.00  True                                                NaN  20000000.0
#  58.00  True                                                NaN         0.0
# -1.00    NaN                                                NaN         NaN
#  35.00  True                                                NaN  11000000.0
#  58.00  True                                                NaN         0.0
#  62.00  True                                                NaN         0.0
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
#  44.00  True                                                NaN  20000000.0
#  98.00  True                                                NaN         0.0
#  52.00  True                                                NaN         0.0
#  16.50   NaN                                                NaN         NaN
#  4.00   True  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
#  30.00  True                                                NaN         0.0
#  60.00  True                                                NaN  20000000.0
#  30.25   NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
#  50.00  True                                                NaN         0.0
# -1.00    NaN                                                NaN         NaN
#  3.60    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
#  12.00  True  {'id': 117693, 'name': 'Balto Collection', 'po...         0.0
# -1.00    NaN                                                NaN         NaN
#  18.00  True  {'id': 3167, 'name': 'Ace Ventura Collection',...  30000000.0
# -1.00    NaN                                                NaN         NaN
# ...      ...                                                ...         ...
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
# -1.00    NaN                                                NaN         NaN
#
#                                                    genres homepage      id  \
#  30.00  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      NaN    9909
#  65.00  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...      NaN   11525
# -1.00                                                 NaN      NaN     NaN
#  16.00  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    4584
# -1.00                                                 NaN      NaN     NaN
#  60.00  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN   17182
#  58.00  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...      NaN   99040
# -1.00                                                 NaN      NaN     NaN
#  35.00                      [{'id': 18, 'name': 'Drama'}]      NaN     687
#  58.00  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...      NaN   99040
#  62.00                     [{'id': 35, 'name': 'Comedy'}]      NaN   10607
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
#  44.00  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...      NaN     577
#  98.00  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN   11062
#  52.00  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...      NaN   49133
#  16.50                                                NaN      NaN     NaN
#  4.00                      [{'id': 35, 'name': 'Comedy'}]      NaN   11862
#  30.00  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      NaN    9909
#  60.00  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN   17182
#  30.25                                                NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
#  50.00  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      NaN  117164
# -1.00                                                 NaN      NaN     NaN
#  3.60                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
#  12.00  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...      NaN   21032
# -1.00                                                 NaN      NaN     NaN
#  18.00  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...      NaN    9273
# -1.00                                                 NaN      NaN     NaN
# ...                                                   ...      ...     ...
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
# -1.00                                                 NaN      NaN     NaN
#
#           imdb_id original_language  \
#  30.00  tt0112792                en
#  65.00  tt0116839                en
# -1.00         NaN               NaN
#  16.00  tt0114388                en
# -1.00         NaN               NaN
#  60.00  tt0116260                en
#  58.00  tt0112714                fr
# -1.00         NaN               NaN
#  35.00  tt0112818                en
#  58.00  tt0112714                fr
#  62.00  tt0116126                en
# -1.00         NaN               NaN
# -1.00         NaN               NaN
#  44.00  tt0114681                en
#  98.00  tt0115907                en
#  52.00  tt0110299                it
#  16.50        NaN               NaN
#  4.00   tt0113041                en
#  30.00  tt0112792                en
#  60.00  tt0116260                en
#  30.25        NaN               NaN
# -1.00         NaN               NaN
#  50.00  tt0109950                en
# -1.00         NaN               NaN
#  3.60         NaN               NaN
# -1.00         NaN               NaN
#  12.00  tt0112453                en
# -1.00         NaN               NaN
#  18.00  tt0112281                en
# -1.00         NaN               NaN
# ...           ...               ...
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
# -1.00         NaN               NaN
#
#                                            original_title  \
#  30.00                                    Dangerous Minds
#  65.00                 Lawnmower Man 2: Beyond Cyberspace
# -1.00                                                 NaN
#  16.00                              Sense and Sensibility
# -1.00                                                 NaN
#  60.00                                     Eye for an Eye
#  58.00                                   Le confessionnal
# -1.00                                                 NaN
#  35.00                                   Dead Man Walking
#  58.00                                   Le confessionnal
#  62.00  Don't Be a Menace to South Central While Drink...
# -1.00                                                 NaN
# -1.00                                                 NaN
#  44.00                                         To Die For
#  98.00                                          City Hall
#  52.00                                           Lamerica
#  16.50                                                NaN
#  4.00                         Father of the Bride Part II
#  30.00                                    Dangerous Minds
#  60.00                                     Eye for an Eye
#  30.25                                                NaN
# -1.00                                                 NaN
#  50.00                                     Guardian Angel
# -1.00                                                 NaN
#  3.60                                                 NaN
# -1.00                                                 NaN
#  12.00                                              Balto
# -1.00                                                 NaN
#  18.00                     Ace Ventura: When Nature Calls
# -1.00                                                 NaN
# ...                                                   ...
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
# -1.00                                                 NaN
#
#                                                  overview  ...  \
#  30.00  Former Marine Louanne Johnson lands a gig teac...  ...
#  65.00  Jobe is resuscitated by Jonathan Walker. He wa...  ...
# -1.00                                                 NaN  ...
#  16.00  Rich Mr. Dashwood dies, leaving his second wif...  ...
# -1.00                                                 NaN  ...
#  60.00  It's fire and brimstone time as grieving mothe...  ...
#  58.00  The year is 1952, in Quebec City. Rachel (16),...  ...
# -1.00                                                 NaN  ...
#  35.00  A justice drama based on a true story about a ...  ...
#  58.00  The year is 1952, in Quebec City. Rachel (16),...  ...
#  62.00  When Ashtray (Shawn Wayans) moves to South Cen...  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
#  44.00  Susan wants to work in television and will the...  ...
#  98.00  The accidental shooting of a boy in New York l...  ...
#  52.00  Fiore, an Italian conman, arrives in post Comm...  ...
#  16.50                                                NaN  ...
#  4.00   Just when George Banks has recovered from his ...  ...
#  30.00  Former Marine Louanne Johnson lands a gig teac...  ...
#  60.00  It's fire and brimstone time as grieving mothe...  ...
#  30.25                                                NaN  ...
# -1.00                                                 NaN  ...
#  50.00  Detective - turned - bodyguard Cynthia McKay (...  ...
# -1.00                                                 NaN  ...
#  3.60                                                 NaN  ...
# -1.00                                                 NaN  ...
#  12.00  An outcast half-wolf risks his life to prevent...  ...
# -1.00                                                 NaN  ...
#  18.00  Summoned from an ashram in Tibet, Ace finds hi...  ...
# -1.00                                                 NaN  ...
# ...                                                   ...  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
# -1.00                                                 NaN  ...
#
#                                                     title  video vote_avg  \
#  30.00                                    Dangerous Minds  False      6.4
#  65.00                 Lawnmower Man 2: Beyond Cyberspace  False      2.8
# -1.00                                                 NaN    NaN      NaN
#  16.00                              Sense and Sensibility  False      7.2
# -1.00                                                 NaN    NaN      NaN
#  60.00                                     Eye for an Eye  False      5.8
#  58.00                                   The Confessional  False      6.5
# -1.00                                                 NaN    NaN      NaN
#  35.00                                   Dead Man Walking  False      7.3
#  58.00                                   The Confessional  False      6.5
#  62.00  Don't Be a Menace to South Central While Drink...  False      6.2
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
#  44.00                                         To Die For  False      6.7
#  98.00                                          City Hall  False      6.0
#  52.00                                           Lamerica  False      7.7
#  16.50                                                NaN    NaN      NaN
#  4.00                         Father of the Bride Part II  False      5.7
#  30.00                                    Dangerous Minds  False      6.4
#  60.00                                     Eye for an Eye  False      5.8
#  30.25                                                NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
#  50.00                                     Guardian Angel  False      6.3
# -1.00                                                 NaN    NaN      NaN
#  3.60                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
#  12.00                                              Balto  False      7.1
# -1.00                                                 NaN    NaN      NaN
#  18.00                     Ace Ventura: When Nature Calls  False      6.1
# -1.00                                                 NaN    NaN      NaN
# ...                                                   ...    ...      ...
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
# -1.00                                                 NaN    NaN      NaN
#
#        vote_count                                               cast  \
#  30.00      249.0  [{'cast_id': 13, 'character': 'Louanne Johnson...
#  65.00       32.0  [{'cast_id': 1, 'character': 'Dr. Benjamin Tra...
# -1.00         NaN                                                NaN
#  16.00      364.0  [{'cast_id': 6, 'character': 'Marianne Dashwoo...
# -1.00         NaN                                                NaN
#  60.00       65.0  [{'cast_id': 1, 'character': 'Karen McCann', '...
#  58.00        2.0  [{'cast_id': 3, 'character': 'Pierre Lamontagn...
# -1.00         NaN                                                NaN
#  35.00      350.0  [{'cast_id': 7, 'character': 'Sister Helen Pre...
#  58.00        2.0  [{'cast_id': 3, 'character': 'Pierre Lamontagn...
#  62.00      192.0  [{'cast_id': 18, 'character': 'Ashtray', 'cred...
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
#  44.00      177.0  [{'cast_id': 4, 'character': 'Suzanne Stone Ma...
#  98.00       67.0  [{'cast_id': 1, 'character': 'Mayor John Pappa...
#  52.00       11.0  [{'cast_id': 2, 'character': 'Gino', 'credit_i...
#  16.50        NaN                                                NaN
#  4.00       173.0  [{'cast_id': 1, 'character': 'George Banks', '...
#  30.00      249.0  [{'cast_id': 13, 'character': 'Louanne Johnson...
#  60.00       65.0  [{'cast_id': 1, 'character': 'Karen McCann', '...
#  30.25        NaN                                                NaN
# -1.00         NaN                                                NaN
#  50.00        3.0  [{'cast_id': 1, 'character': 'Cynthia Mckay', ...
# -1.00         NaN                                                NaN
#  3.60         NaN                                                NaN
# -1.00         NaN                                                NaN
#  12.00      423.0  [{'cast_id': 1, 'character': 'Balto (voice)', ...
# -1.00         NaN                                                NaN
#  18.00     1128.0  [{'cast_id': 1, 'character': 'Ace Ventura', 'c...
# -1.00         NaN                                                NaN
# ...           ...                                                ...
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
# -1.00         NaN                                                NaN
#
#                                                      crew  WEEK      MONTH  \
#  30.00  [{'credit_id': '52fe4546c3a36847f80c4e4b', 'de...  32.0     August
#  65.00  [{'credit_id': '52fe44529251416c750309d3', 'de...   2.0    January
# -1.00                                                 NaN   NaN        NaN
#  16.00  [{'credit_id': '52fe43cec3a36847f807101f', 'de...  50.0   December
# -1.00                                                 NaN   NaN        NaN
#  60.00  [{'credit_id': '52fe470d9251416c7508c48b', 'de...   2.0    January
#  58.00  [{'credit_id': '52fe4a259251416c750df449', 'de...  39.0  September
# -1.00                                                 NaN   NaN        NaN
#  35.00  [{'credit_id': '52fe426ac3a36847f801cf35', 'de...  52.0   December
#  58.00  [{'credit_id': '52fe4a259251416c750df449', 'de...  39.0  September
#  62.00  [{'credit_id': '52fe43929251416c750159f9', 'de...   2.0    January
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
#  44.00  [{'credit_id': '52fe4255c3a36847f8015f49', 'de...  20.0        May
#  98.00  [{'credit_id': '571fb8ccc3a368775b0032ff', 'de...   7.0   February
#  52.00  [{'credit_id': '52fe4787c3a36847f813acf7', 'de...  52.0    January
#  16.50                                                NaN   NaN        NaN
#  4.00   [{'credit_id': '52fe44959251416c75039ed7', 'de...   6.0   February
#  30.00  [{'credit_id': '52fe4546c3a36847f80c4e4b', 'de...  32.0     August
#  60.00  [{'credit_id': '52fe470d9251416c7508c48b', 'de...   2.0    January
#  30.25                                                NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
#  50.00  [{'credit_id': '52fe4babc3a36847f820ea31', 'de...  47.0   November
# -1.00                                                 NaN   NaN        NaN
#  3.60                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
#  12.00  [{'credit_id': '593f24b9c3a3680369002371', 'de...  51.0   December
# -1.00                                                 NaN   NaN        NaN
#  18.00  [{'credit_id': '52fe44dfc3a36847f80af28b', 'de...  45.0   November
# -1.00                                                 NaN   NaN        NaN
# ...                                                   ...   ...        ...
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
# -1.00                                                 NaN   NaN        NaN
#
#           YEAR BUDGET_MIL
#  30.00  1995.0       -1.0
#  65.00  1996.0       -1.0
# -1.00      NaN        NaN
#  16.00  1995.0       16.5
# -1.00      NaN        NaN
#  60.00  1996.0       20.0
#  58.00  1995.0       -1.0
# -1.00      NaN        NaN
#  35.00  1995.0       11.0
#  58.00  1995.0       -1.0
#  62.00  1996.0       -1.0
# -1.00      NaN        NaN
# -1.00      NaN        NaN
#  44.00  1995.0       20.0
#  98.00  1996.0       -1.0
#  52.00  1994.0       -1.0
#  16.50     NaN        NaN
#  4.00   1995.0       -1.0
#  30.00  1995.0       -1.0
#  60.00  1996.0       20.0
#  30.25     NaN        NaN
# -1.00      NaN        NaN
#  50.00  1994.0       -1.0
# -1.00      NaN        NaN
#  3.60      NaN        NaN
# -1.00      NaN        NaN
#  12.00  1995.0       -1.0
# -1.00      NaN        NaN
#  18.00  1995.0       30.0
# -1.00      NaN        NaN
# ...        ...        ...
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
# -1.00      NaN        NaN
#
# [45522 rows x 30 columns]

# %% [markdown]
# ### "genres" column

# %%
#Parsing items in Genres column (originally a list of dictionary)

df['GENRES'] = df['genres'].apply(lambda yaml_obj: [dict_obj['name']
                                for dict_obj in yaml.load(yaml_obj, Loader=yaml.FullLoader)])
df['GENRES'].head()
# Out:
# 0     [Animation, Comedy, Family]
# 1    [Adventure, Fantasy, Family]
# 2               [Romance, Comedy]
# 3        [Comedy, Drama, Romance]
# 4                        [Comedy]
# Name: GENRES, dtype: object

# %% [markdown]
# ### "production companies" column

# %%
def _parse_list_of_dicts(_yaml_obj):
    try:
        return [_dict_obj["name"] for _dict_obj in yaml.load(_yaml_obj, Loader=yaml.FullLoader)]
    except:
        return []

df['PRODUCER'] = df['production_companies'].apply(_parse_list_of_dicts)
df["PRODUCER"].head()

#Parsing items into 'PRODUCER' colum (originally a list of dictionary)
# df['PRODUCER'] = df['production_companies'].apply(lambda yaml_obj: [dict_obj['name'] 
#                                     for dict_obj in yaml.load(yaml_obj, Loader=yaml.FullLoader)])
# Out:
# 0                            [Pixar Animation Studios]
# 1    [TriStar Pictures, Teitler Film, Interscope Co...
# 2                       [Warner Bros., Lancaster Gate]
# 3             [Twentieth Century Fox Film Corporation]
# 4         [Sandollar Productions, Touchstone Pictures]
# Name: PRODUCER, dtype: object

# %% [markdown]
# ### "production countries" column

# %%
def _parse_list_of_dicts(_yaml_obj):
    try:
        return [_dict_obj["iso_3166_1"] for _dict_obj in yaml.load(_yaml_obj, Loader=yaml.FullLoader)]
    except:
        return []

df['COUNTRIES'] = df['production_countries'].apply(_parse_list_of_dicts)
df["COUNTRIES"].head()

# df['COUNTRIES'] = df['production_countries'].apply(lambda yaml_obj: [dict_obj['name'] for dict_obj in yaml.load(yaml_obj, Loader=yaml.FullLoader)])
# Out:
# 0    [US]
# 1    [US]
# 2    [US]
# 3    [US]
# 4    [US]
# Name: COUNTRIES, dtype: object

# %% [markdown]
# ### "revenue" column

# %%
#Making unit $million for readibility
df['REVENUE_MIL'] = df['revenue'] / 1000000

#Reassigning 0 values to a negative value for easy filtering
def revenue_no_zero(value):
    if value > 1:
        return value
    else:
        return -1


df['REVENUE_MIL'] = df['REVENUE_MIL'].apply(revenue_no_zero)
    

df['REVENUE_MIL'].describe()
# Out:
# count    45522.000000
# mean        10.327427
# std         64.444101
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max       2787.965087
# Name: REVENUE_MIL, dtype: float64

# %% [markdown]
# ### Retrieve producers, directors, and writers from "crew" column

# %%
df_null = df.loc[df['crew'].isna()]

# %%
list_dir = [dict_obj['name'] for dict_obj in yaml.load(df_crew['crew'][5], Loader=yaml.FullLoader) if dict_obj['department'] == 'Directing']
list_dir
# Out:
# ['Michael Mann', 'Cate Hardman', 'Michael Waxman']

# %%
def get_directors(yaml_obj):
    directors = []
    try:
        yaml_obj_read = yaml.load(yaml_obj, Loader=yaml.FullLoader)
        for dict_obj in yaml_obj_read:
            if dict_obj['department'] == 'Directing':
                directors.append(dict_obj['name'])
    except:
        pass
    return directors

df['Directors'] = df['crew'].apply(get_directors)

# %%
df['Directors'].head()
# Out:
# 0    [John Lasseter, Roman Figun, Desirée Mourad]
# 1                                  [Joe Johnston]
# 2                                 [Howard Deutch]
# 3                               [Forest Whitaker]
# 4                                 [Charles Shyer]
# Name: Directors, dtype: object

# %%
def get_writers(yaml_obj):
    writers = []
    try:
        yaml_obj_read = yaml.load(yaml_obj, Loader=yaml.FullLoader)
        for dict_obj in yaml_obj_read:
            if dict_obj['department'] == 'Writing':
                writers.append(dict_obj['name'])
    except:
        pass
    return writers

df['Writers'] = df['crew'].apply(get_writers)

# %%
df['Writers'].head()
# Out:
# 0    [Joss Whedon, Andrew Stanton, Joel Cohen, Alec...
# 1    [Jonathan Hensleigh, Chris van Allsburg, Greg ...
# 2           [Mark Steven Johnson, Mark Steven Johnson]
# 3        [Ronald Bass, Terry McMillan, Terry McMillan]
# 4                       [Nancy Meyers, Albert Hackett]
# Name: Writers, dtype: object

# %%
def get_expro(yaml_obj):
    expros = []
    try:
        yaml_obj_read = yaml.load(yaml_obj, Loader=yaml.FullLoader)
        for dict_obj in yaml_obj_read:
            if dict_obj['job'] == 'Executive Producer':
                expros.append(dict_obj['name'])
    except:
        pass
    return expros

df['ExPro'] = df['crew'].apply(get_expro)

# %%
df['ExPro'].head()
# Out:
# 0                        [Ed Catmull, Steve Jobs]
# 1    [Larry J. Franco, Ted Field, Robert W. Cort]
# 2                                              []
# 3                                [Terry McMillan]
# 4                                              []
# Name: ExPro, dtype: object

# %% [markdown]
# ### Retrieve top 3 actor names from "cast" column¶

# %%
#Defining a function to parse top 3 actor names in each movie.
#The function ignores entries that trigger an error

def get_actors(yaml_obj):
    actors = []
    try:
        yaml_obj_read = yaml.load(yaml_obj, Loader=yaml.FullLoader)
        for dict_obj in yaml_obj_read:
            if dict_obj['order'] < 3:
                actors.append(dict_obj['name'])
    except:
        pass
    return actors

df['ACTORS'] = df['cast'].apply(get_actors)

# %%
df['ACTORS'].head()
# Out:
# 0                  [Tom Hanks, Tim Allen, Don Rickles]
# 1       [Robin Williams, Jonathan Hyde, Kirsten Dunst]
# 2           [Walter Matthau, Jack Lemmon, Ann-Margret]
# 3    [Whitney Houston, Angela Bassett, Loretta Devine]
# 4           [Steve Martin, Diane Keaton, Martin Short]
# Name: ACTORS, dtype: object

# %% [markdown]
# ### Adding column 'Profit'.

# %%
df["PROFIT"] = df["REVENUE_MIL"] - df["BUDGET_MIL"]
df["PROFIT"].describe()
# Out:
# count    45522.000000
# mean         6.958029
# std         52.135687
# min       -165.710090
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       2550.965087
# Name: PROFIT, dtype: float64

# %% [markdown]
# ### End of processing by column.
# #### Removing unwanted columns for the final dataframe

# %%
df.columns
# Out:
# Index(['adult', 'collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries', 'date',
#        'revenue', 'runtime', 'languages', 'status', 'tagline', 'title',
#        'video', 'vote_avg', 'vote_count', 'cast', 'crew', 'WEEK', 'MONTH',
#        'YEAR', 'BUDGET_MIL', 'GENRES', 'PRODUCER', 'COUNTRIES', 'REVENUE_MIL',
#        'PROFIT'],
#       dtype='object')

# %%
#Removing unwanted columns for the final dataframe
df = df.drop(columns = ['collection','budget','genres','homepage','poster_path','languages', \
                        'production_companies','production_countries'])

# %%
#Exporting final dataframe to dir data/final/movie_dataset_df, making sure that the file is compressed to save memory
df.to_csv('data/final/movie_dataset_df.csv.gz', index=False, compression='gzip')

# %% [markdown]
# ## Additional: getting a list of departments and jobs involved in a movie for future work

# %%
list_dept = [dict_obj['department'] for dict_obj in yaml.load(df_crew['crew'][5], Loader=yaml.FullLoader)]
set(list_dept)
# Out:
# {'Art',
#  'Camera',
#  'Costume & Make-Up',
#  'Crew',
#  'Directing',
#  'Editing',
#  'Lighting',
#  'Production',
#  'Sound',
#  'Visual Effects',
#  'Writing'}

# %%
list_job = [dict_obj['job'] for dict_obj in yaml.load(df_crew['crew'][5], Loader=yaml.FullLoader)]
set(list_job)
# Out:
# {'Additional Soundtrack',
#  'Art Department Coordinator',
#  'Art Direction',
#  'Assistant Art Director',
#  'Assistant Costume Designer',
#  'Assistant Director',
#  'Associate Producer',
#  'Camera Operator',
#  'Casting',
#  'Casting Associate',
#  'Construction Coordinator',
#  'Costume Design',
#  'Costume Supervisor',
#  'Dialogue Editor',
#  'Digital Effects Supervisor',
#  'Director',
#  'Director of Photography',
#  'Editor',
#  'Executive Producer',
#  'First Assistant Camera',
#  'First Assistant Editor',
#  'Hairstylist',
#  'Key Hair Stylist',
#  'Makeup Artist',
#  'Music Editor',
#  'Music Supervisor',
#  'Original Music Composer',
#  'Producer',
#  'Production Design',
#  'Rigging Gaffer',
#  'Screenplay',
#  'Script Supervisor',
#  'Set Costumer',
#  'Set Decoration',
#  'Sound Re-Recording Mixer',
#  'Sound Recordist',
#  'Special Effects',
#  'Special Effects Coordinator',
#  'Steadicam Operator',
#  'Still Photographer',
#  'Stunt Coordinator',
#  'Stunts',
#  'Supervising Sound Editor',
#  'Technical Supervisor',
#  'Unit Production Manager',
#  'Visual Effects Supervisor'}
