# %% [markdown]
# # Working Notebook for the Movie Project
#
# This is the working notebook, not part of the final package.
#
# ## Github repo:
# https://github.com/akharina/dc-ds_movie_project.git
#
#
# ## Data directory:
# * data/raw          : provided datasets
# * data/raw/kaggle   : data from [Kaggle](https://www.kaggle.com/rounakbanik/the-movies-dataset)
#
#
#
# ## Workflow:
# 1. Exploring datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
imdb_basic = pd.read_csv('data/raw/imdb.title.basics.csv.gz')
imdb_basic.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
tn_budget = pd.read_csv('data/raw/tn.movie_budgets.csv.gz')
tn_budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
tn_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.1+ KB

# %%
imdb_ratings = pd.read_csv('data/raw/imdb.title.ratings.csv.gz')
imdb_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
imdb_principals = pd.read_csv('data/raw/imdb.title.principals.csv.gz')
imdb_principals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
# tconst        1028186 non-null object
# ordering      1028186 non-null int64
# nconst        1028186 non-null object
# category      1028186 non-null object
# job           177684 non-null object
# characters    393360 non-null object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB

# %%
imdb_principals.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
bom = pd.read_csv('data/raw/bom.movie_gross.csv.gz')
bom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
tmdb = pd.read_csv('data/raw/tmdb.movies.csv.gz')
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
# Unnamed: 0           26517 non-null int64
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
imdb_names = pd.read_csv('data/raw/imdb.name.basics.csv.gz')
imdb_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
# nconst                606648 non-null object
# primary_name          606648 non-null object
# birth_year            82736 non-null float64
# death_year            6783 non-null float64
# primary_profession    555308 non-null object
# known_for_titles      576444 non-null object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB

# %%
kaggle_movies = pd.read_csv('data/raw/kaggle/movies_metadata.csv')
kaggle_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = kaggle_movies.copy()

#Removing columns 'homepage' and 'poster_path'
df = df.drop(columns = ['homepage', 'poster_path'],inplace=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 22 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(4), object(18)
# memory usage: 7.6+ MB

# %%
#Renaming column names into shorter, more meaningful names
df = df.rename(columns={'id':'kaggle_id','belongs_to_collection':'collection','spoken_languages':'languages','release_date': 'date', 'vote_average': 'vote_avg'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 22 columns):
# adult                   45466 non-null object
# collection              4494 non-null object
# budget                  45466 non-null object
# genres                  45466 non-null object
# kaggle_id               45466 non-null object
# imdb_id                 45449 non-null object
# original_language       45455 non-null object
# original_title          45466 non-null object
# overview                44512 non-null object
# popularity              45461 non-null object
# production_companies    45463 non-null object
# production_countries    45463 non-null object
# date                    45379 non-null object
# revenue                 45460 non-null float64
# runtime                 45203 non-null float64
# languages               45460 non-null object
# status                  45379 non-null object
# tagline                 20412 non-null object
# title                   45460 non-null object
# video                   45460 non-null object
# vote_avg                45460 non-null float64
# vote_count              45460 non-null float64
# dtypes: float64(4), object(18)
# memory usage: 7.6+ MB

# %%
diff_title = df.loc[df.title != df.original_title][['title','original_title']]
len(diff_title)
# Out:
# 11402

# %%
len(df.imdb_id.unique())
# Out:
# 45418

# %%
#Changing column 'adult' to boolean
df['adult'] = df['adult'].astype('bool')
df.adult.dtype
# Out:
# dtype('bool')

# %% [markdown]
# ### Cleaning up 'date' column

# %%
df[['date']].head()
# Out:
#          date
# 0  1995-10-30
# 1  1995-12-15
# 2  1995-12-22
# 3  1995-12-22
# 4  1995-02-10

# %%
#Changing null values in column 'date' into an impossible date
df['date'] = df['date'].fillna('1800-01-01')

# %%
df['date'].isnull().sum()
# Out:
# 0

# %%
#check for unusual values in 'date' columns: proper date should have 10
#characters 

df['date'].apply(len).value_counts()
# Out:
# 10    45463
# 2         2
# 1         1
# Name: date, dtype: int64

# %%
#Checking the index of the weird values above
weird_date = df['date'].loc[df['date'].apply(len) < 10]
weird_date
# Out:
# 19730     1
# 29503    12
# 35587    22
# Name: date, dtype: object

# %%
#Removing those rows
df = df.drop(index=list(weird_date.index))
df['date'].apply(len).value_counts()
# Out:
# 10    45463
# Name: date, dtype: int64

# %%
#Changing column 'date' to datetime
df['date'] = pd.to_datetime(df['date'])

# %%
df['date'].max()
# Out:
# Timestamp('2020-12-16 00:00:00')

# %%
#Visualizing 'date' column 
plt.hist(df['date'],bins=100)
plt.show()

# %% [markdown]
# ### Looking into 'status' column

# %%
df['status'].value_counts()
# Out:
# Released           45014
# Rumored              230
# Post Production       98
# In Production         20
# Planned               15
# Canceled               2
# Name: status, dtype: int64

# %% [markdown]
# #### Parsing directories within column entries into a list

# %%
# !pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in /anaconda3/lib/python3.7/site-packages (5.1.1)

# %%
import yaml

# %%
df['genres'].head()
# Out:
# 0    [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1    [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2    [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                       [{'id': 35, 'name': 'Comedy'}]
# Name: genres, dtype: object

# %%
yaml.load(df['genres'][0])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
[x['name'] for x in yaml.load(df['genres'][0])]
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.
# ['Animation', 'Comedy', 'Family']

# %%
df['GENRES'] = df['genres'].apply(lambda yaml_obj: [dict_obj['name'] for dict_obj in yaml.load(yaml_obj)])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.

# %%
df['GENRES'].head()
# Out:
# 0     [Animation, Comedy, Family]
# 1    [Adventure, Fantasy, Family]
# 2               [Romance, Comedy]
# 3        [Comedy, Drama, Romance]
# 4                        [Comedy]
# Name: GENRES, dtype: object

# %%
df['collection'].isna().sum()
# Out:
# 40972

# %%
#Filling null value in 'collection' column with an empty dictionary
df['collection'].fillna("{'name':''}",inplace=True)

# %%
yaml.load(df['collection'][0])['name']
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.
# 'Toy Story Collection'

# %%
#Parsing 'collection' column and get 'collection name'
df['COLLECTION'] = df['collection'].apply(lambda yaml_obj: yaml.load(yaml_obj)['name'])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
df['COLLECTION'].head()
# Out:
# 0              Toy Story Collection
# 1
# 2         Grumpy Old Men Collection
# 3
# 4    Father of the Bride Collection
# Name: COLLECTION, dtype: object

# %%
df_null = df.loc[df['languages'].isna()]
df = df.drop(index = list(df_null.index))

# %%
#Parsing 'languages' column into a list
df['LANGUAGES'] = df['languages'].apply(lambda yaml_obj: [dict_obj['name'] for dict_obj in yaml.load(yaml_obj)])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
df['LANGUAGES'].head()
# Out:
# 0              [English]
# 1    [English, Français]
# 2              [English]
# 3              [English]
# 4              [English]
# Name: LANGUAGES, dtype: object

# %%
df['production_companies'].isna().sum()
# Out:
# 0

# %%
yaml.load(df['production_companies'][0])[0]['name']
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.
# 'Pixar Animation Studios'

# %%
df['PRODUCER'] = df['production_companies'].apply(lambda yaml_obj: [dict_obj['name'] for dict_obj in yaml.load(yaml_obj)])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.

# %%
df['PRODUCER'].head()
# Out:
# 0                            [Pixar Animation Studios]
# 1    [TriStar Pictures, Teitler Film, Interscope Co...
# 2                       [Warner Bros., Lancaster Gate]
# 3             [Twentieth Century Fox Film Corporation]
# 4         [Sandollar Productions, Touchstone Pictures]
# Name: PRODUCER, dtype: object

# %%
df['COUNTRIES'] = df['production_countries'].apply(lambda yaml_obj: [dict_obj['name'] for dict_obj in yaml.load(yaml_obj)])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.

# %%
df[df['video'] == True].head()
# Out:
#        adult                                         collection budget  \
# 5492    True                                        {'name':''}      0
# 11469   True  {'id': 123438, 'name': 'Loose Change Collectio...   5000
# 13564   True                                        {'name':''}      0
# 14271   True  {'id': 190135, 'name': 'Love Hina Collection',...      0
# 14608   True                                        {'name':''}      0
#
#                                                   genres kaggle_id    imdb_id  \
# 5492   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...     15173  tt0298388
# 11469                [{'id': 99, 'name': 'Documentary'}]     14277  tt0831315
# 13564                [{'id': 99, 'name': 'Documentary'}]    284117  tt1198399
# 14271  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...     44685  tt0416938
# 14608  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...     35148  tt1512792
#
#       original_language                          original_title  \
# 5492                 en              Jonah: A VeggieTales Movie
# 11469                en               Loose Change: 2nd Edition
# 13564                en                                   Fitna
# 14271                ja              ラブひな 春スペシャル ～キミサクラチルナカレ!!～
# 14608                en  Playmobil: The Secret of Pirate Island
#
#                                                 overview popularity  ...  \
# 5492   Get ready as Bob the Tomato, Larry the Cucumbe...    1.73418  ...
# 11469  What if...September 11th was not a surprise at...   0.651714  ...
# 13564  A short film in which Quran verses are shown a...   0.040068  ...
# 14271  The tests have come, and Keitaro can only hope...    1.78571  ...
# 14608  Ahoy, matey! Your Favorite Playmobil toys have...   0.014168  ...
#
#                                  tagline  \
# 5492       Fresh Fish. Mixed Vegetables.
# 11469      What really happened on 9/11?
# 13564                                NaN
# 14271  Spring break... Love Hina Style!!
# 14608                                NaN
#
#                                               title video  vote_avg  \
# 5492                     Jonah: A VeggieTales Movie  True       6.4
# 11469                     Loose Change: 2nd Edition  True       6.3
# 13564                                         Fitna  True       1.0
# 14271  Love Hina Spring Special - I Wish Your Dream  True       4.7
# 14608        Playmobil: The Secret of Pirate Island  True       0.0
#
#        vote_count                                             GENRES  \
# 5492         22.0  [Action, Adventure, Animation, Comedy, Family,...
# 11469        16.0                                      [Documentary]
# 13564         1.0                                      [Documentary]
# 14271         3.0                [Comedy, Romance, Animation, Music]
# 14608         0.0               [Action, Adventure, Family, Fantasy]
#
#                     COLLECTION  \
# 5492
# 11469  Loose Change Collection
# 13564
# 14271     Love Hina Collection
# 14608
#
#                                                LANGUAGES  \
# 5492                                    [Český, English]
# 11469                                          [English]
# 13564                              [English, Nederlands]
# 14271                                              [日本語]
# 14608  [Français, English, Norsk, Português, ภาษาไทย,...
#
#                          PRODUCER                   COUNTRIES
# 5492       [Big Idea Productions]  [United States of America]
# 11469  [Polar Film   Medien GmbH]  [United States of America]
# 13564                          []               [Netherlands]
# 14271           [TV Tokyo, Xebec]                     [Japan]
# 14608                          []                          []
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['adult', 'collection', 'budget', 'genres', 'kaggle_id', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'date', 'revenue',
#        'runtime', 'languages', 'status', 'tagline', 'title', 'video',
#        'vote_avg', 'vote_count', 'GENRES', 'COLLECTION', 'LANGUAGES',
#        'PRODUCER', 'COUNTRIES'],
#       dtype='object')

# %%
df = df.drop(columns = ['collection','genres','languages','production_companies','production_countries'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45460 entries, 0 to 45465
# Data columns (total 22 columns):
# adult                45460 non-null bool
# budget               45460 non-null object
# kaggle_id            45460 non-null object
# imdb_id              45443 non-null object
# original_language    45449 non-null object
# original_title       45460 non-null object
# overview             44506 non-null object
# popularity           45460 non-null object
# date                 45460 non-null datetime64[ns]
# revenue              45460 non-null float64
# runtime              45203 non-null float64
# status               45379 non-null object
# tagline              20412 non-null object
# title                45460 non-null object
# video                45460 non-null object
# vote_avg             45460 non-null float64
# vote_count           45460 non-null float64
# GENRES               45460 non-null object
# COLLECTION           45460 non-null object
# LANGUAGES            45460 non-null object
# PRODUCER             45460 non-null object
# COUNTRIES            45460 non-null object
# dtypes: bool(1), datetime64[ns](1), float64(4), object(16)
# memory usage: 8.9+ MB

# %%
df.isna().sum()
# Out:
# adult                    0
# budget                   0
# kaggle_id                0
# imdb_id                 17
# original_language       11
# original_title           0
# overview               954
# popularity               0
# date                     0
# revenue                  0
# runtime                257
# status                  81
# tagline              25048
# title                    0
# video                    0
# vote_avg                 0
# vote_count               0
# GENRES                   0
# COLLECTION               0
# LANGUAGES                0
# PRODUCER                 0
# COUNTRIES                0
# dtype: int64

# %%
df.loc[df['imdb_id'].isna() == True][['title','revenue']]
# Out:
#                                                    title  revenue
# 8966                                            Delusion      0.0
# 13757                                               Show      0.0
# 13821  How I Unleashed World War II Part III: Among F...      0.0
# 17382                                        Dreamkiller      0.0
# 17510                                         The Winner      0.0
# 18959       Before The Dinosaurs - Walking With Monsters      0.0
# 19322                                          Endeavour      0.0
# 20806                                 Hulk vs. Wolverine      0.0
# 20937                          Last Stand at Saber River      0.0
# 21916                                       Running Wild      0.0
# 22987                                                  8      0.0
# 23744  Gunbuster vs Diebuster Aim for the Top! The GA...      0.0
# 33753                                         The Master      0.0
# 36955                                     Doraemon:貓狗時空傳      0.0
# 40809                     H2O Just Add Water - The Movie      0.0
# 41832                                  Le passe-muraille      0.0
# 45070                     The Garden of Afflictions 2017      0.0

# %%
#Dropping rows without imdb id (there are only 17 of them and all have 0 revenues)

not_in_imdb = df.loc[df['imdb_id'].isna() == True].index
df.drop(not_in_imdb, inplace = True)

# %%
#Changing 'budget' column to numeric format
df['budget'] = pd.to_numeric(df['budget'])

# %%
print(f"Number of movies with no budget data is {len(df[df['budget'] < 100000])}")
print(f"Number of movies with no revenue data is {len(df[df['revenue'] < 100000])}")
# Out:
# Number of movies with no budget data is 37109
# Number of movies with no revenue data is 38616

# %%
#Exporting main dataframe to dir data/temp/movie_df
df.to_csv('data/temp/movie_df', index=False)

# %%
df_money = df[(df['budget'] > 500) & (df['revenue'] > 500)]
df_money.describe()
# Out:
#              budget       revenue      runtime     vote_avg    vote_count
# count  5.312000e+03  5.312000e+03  5311.000000  5312.000000   5312.000000
# mean   3.148126e+07  9.145629e+07   109.937677     6.279047    740.976092
# std    4.027580e+07  1.669076e+08    21.997108     0.913352   1257.204703
# min    2.500000e+03  1.404000e+03     0.000000     0.000000      0.000000
# 25%    5.900000e+06  7.545185e+06    95.000000     5.700000     80.750000
# 50%    1.700000e+07  3.051161e+07   106.000000     6.300000    282.000000
# 75%    4.000000e+07  1.005295e+08   120.000000     6.900000    813.000000
# max    3.800000e+08  2.787965e+09   338.000000     9.100000  14075.000000

# %%
#Exporting dataframe subset to dir data/temp/movie_money_df, making sure that the file is compressed to save memory
df_money.to_csv('data/temp/movie_money_df', index=False, compression='gzip')

# %% [markdown]
# ### Now we will move to the credit datasets to retrieve producer / director / writer

# %%
df_crew = pd.read_csv('data/raw/kaggle/credits.csv.gz')
df_crew.crew[0]
# Out:
# '[{\'credit_id\': \'52fe4284c3a36847f8024f49\', \'department\': \'Directing\', \'gender\': 2, \'id\': 7879, \'job\': \'Director\', \'name\': \'John Lasseter\', \'profile_path\': \'/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f4f\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12891, \'job\': \'Screenplay\', \'name\': \'Joss Whedon\', \'profile_path\': \'/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f55\', \'department\': \'Writing\', \'gender\': 2, \'id\': 7, \'job\': \'Screenplay\', \'name\': \'Andrew Stanton\', \'profile_path\': \'/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f5b\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12892, \'job\': \'Screenplay\', \'name\': \'Joel Cohen\', \'profile_path\': \'/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f61\', \'department\': \'Writing\', \'gender\': 0, \'id\': 12893, \'job\': \'Screenplay\', \'name\': \'Alec Sokolow\', \'profile_path\': \'/v79vlRYi94BZUQnkkyznbGUZLjT.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f67\', \'department\': \'Production\', \'gender\': 1, \'id\': 12894, \'job\': \'Producer\', \'name\': \'Bonnie Arnold\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f6d\', \'department\': \'Production\', \'gender\': 0, \'id\': 12895, \'job\': \'Executive Producer\', \'name\': \'Ed Catmull\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f73\', \'department\': \'Production\', \'gender\': 2, \'id\': 12896, \'job\': \'Producer\', \'name\': \'Ralph Guggenheim\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f79\', \'department\': \'Production\', \'gender\': 2, \'id\': 12897, \'job\': \'Executive Producer\', \'name\': \'Steve Jobs\', \'profile_path\': \'/mOMP3SwD5qWQSR0ldCIByd3guTV.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f8b\', \'department\': \'Editing\', \'gender\': 2, \'id\': 8, \'job\': \'Editor\', \'name\': \'Lee Unkrich\', \'profile_path\': \'/bdTCCXjgOV3YyaNmLGYGOxFQMOc.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f91\', \'department\': \'Art\', \'gender\': 2, \'id\': 7883, \'job\': \'Art Direction\', \'name\': \'Ralph Eggleston\', \'profile_path\': \'/uUfcGKDsKO1aROMpXRs67Hn6RvR.jpg\'}, {\'credit_id\': \'598331bf925141421201044b\', \'department\': \'Editing\', \'gender\': 2, \'id\': 1168870, \'job\': \'Editor\', \'name\': \'Robert Gordon\', \'profile_path\': None}, {\'credit_id\': \'5892168cc3a36809660095f9\', \'department\': \'Sound\', \'gender\': 0, \'id\': 1552883, \'job\': \'Foley Editor\', \'name\': \'Mary Helen Leasman\', \'profile_path\': None}, {\'credit_id\': \'5531824d9251415289000945\', \'department\': \'Visual Effects\', \'gender\': 0, \'id\': 1453514, \'job\': \'Animation\', \'name\': \'Kim Blanchette\', \'profile_path\': None}, {\'credit_id\': \'589215969251412dcb009bf6\', \'department\': \'Sound\', \'gender\': 0, \'id\': 1414182, \'job\': \'ADR Editor\', \'name\': \'Marilyn McCoppen\', \'profile_path\': None}, {\'credit_id\': \'589217099251412dc500a018\', \'department\': \'Sound\', \'gender\': 2, \'id\': 7885, \'job\': \'Orchestrator\', \'name\': \'Randy Newman\', \'profile_path\': \'/w0JzfoiM25nrnxYOzosPHRq6mlE.jpg\'}, {\'credit_id\': \'5693e6b29251417b0e0000e3\', \'department\': \'Editing\', \'gender\': 0, \'id\': 1429549, \'job\': \'Color Timer\', \'name\': \'Dale E. Grahn\', \'profile_path\': None}, {\'credit_id\': \'572e2522c3a36869e6001a9c\', \'department\': \'Visual Effects\', \'gender\': 0, \'id\': 7949, \'job\': \'CG Painter\', \'name\': \'Robin Cooper\', \'profile_path\': None}, {\'credit_id\': \'574f12309251415ca1000012\', \'department\': \'Writing\', \'gender\': 2, \'id\': 7879, \'job\': \'Original Story\', \'name\': \'John Lasseter\', \'profile_path\': \'/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg\'}, {\'credit_id\': \'574f1240c3a3682e7300001c\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12890, \'job\': \'Original Story\', \'name\': \'Pete Doct ...

# %%
list_dept = [dict_obj['department'] for dict_obj in yaml.load(df_crew['crew'][5])]
set(list_dept)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.
# {'Art',
#  'Camera',
#  'Costume & Make-Up',
#  'Crew',
#  'Directing',
#  'Editing',
#  'Lighting',
#  'Production',
#  'Sound',
#  'Visual Effects',
#  'Writing'}

# %%
list_job = [dict_obj['job'] for dict_obj in yaml.load(df_crew['crew'][5])]
set(list_job)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.
# {'Additional Soundtrack',
#  'Art Department Coordinator',
#  'Art Direction',
#  'Assistant Art Director',
#  'Assistant Costume Designer',
#  'Assistant Director',
#  'Associate Producer',
#  'Camera Operator',
#  'Casting',
#  'Casting Associate',
#  'Construction Coordinator',
#  'Costume Design',
#  'Costume Supervisor',
#  'Dialogue Editor',
#  'Digital Effects Supervisor',
#  'Director',
#  'Director of Photography',
#  'Editor',
#  'Executive Producer',
#  'First Assistant Camera',
#  'First Assistant Editor',
#  'Hairstylist',
#  'Key Hair Stylist',
#  'Makeup Artist',
#  'Music Editor',
#  'Music Supervisor',
#  'Original Music Composer',
#  'Producer',
#  'Production Design',
#  'Rigging Gaffer',
#  'Screenplay',
#  'Script Supervisor',
#  'Set Costumer',
#  'Set Decoration',
#  'Sound Re-Recording Mixer',
#  'Sound Recordist',
#  'Special Effects',
#  'Special Effects Coordinator',
#  'Steadicam Operator',
#  'Still Photographer',
#  'Stunt Coordinator',
#  'Stunts',
#  'Supervising Sound Editor',
#  'Technical Supervisor',
#  'Unit Production Manager',
#  'Visual Effects Supervisor'}

# %%
list_dir = [dict_obj['name'] for dict_obj in yaml.load(df_crew['crew'][5]) if dict_obj['department'] == 'Directing']
list_dir
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.
# ['Michael Mann', 'Cate Hardman', 'Michael Waxman']

# %%
df_crew['Directors'] = df_crew['crew'].apply(lambda yaml_obj: [dict_obj['name'] for dict_obj in yaml.load(yaml_obj) if dict_obj['department'] == 'Directing']).copy()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.

# %%
df_crew['Directors'].head()
# Out:
# 0    [John Lasseter, Roman Figun, Desirée Mourad]
# 1                                  [Joe Johnston]
# 2                                 [Howard Deutch]
# 3                               [Forest Whitaker]
# 4                                 [Charles Shyer]
# Name: Directors, dtype: object

# %%
df_crew['Writers'] = df_crew['crew'].apply(lambda yaml_obj: [dict_obj['name'] for dict_obj in yaml.load(yaml_obj) if dict_obj['department'] == 'Writing'])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.

# %%
df_crew['Writers'].head()
# Out:
# 0    [Joss Whedon, Andrew Stanton, Joel Cohen, Alec...
# 1    [Jonathan Hensleigh, Chris van Allsburg, Greg ...
# 2           [Mark Steven Johnson, Mark Steven Johnson]
# 3        [Ronald Bass, Terry McMillan, Terry McMillan]
# 4                       [Nancy Meyers, Albert Hackett]
# Name: Writers, dtype: object

# %%
df_crew['ExPro'] = df_crew['crew'].apply(lambda yaml_obj: [dict_obj['name'] for dict_obj in yaml.load(yaml_obj) if dict_obj['job'] == 'Executive Producer'])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.

# %%
df_crew['ExPro'].head()
# Out:
# 0                        [Ed Catmull, Steve Jobs]
# 1    [Larry J. Franco, Ted Field, Robert W. Cort]
# 2                                              []
# 3                                [Terry McMillan]
# 4                                              []
# Name: ExPro, dtype: object

# %%
list_act = [dict_obj['name'] for dict_obj in yaml.load(df_crew['cast'][5555]) if dict_obj['order'] < 3]
list_act
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.
# ['Charles Bronson', 'Jan-Michael Vincent', 'Jill Ireland']

# %%
def get_actors(yaml_obj):
    actors = []
    try:
        yaml_obj_read = yaml.load(yaml_obj)
        for dict_obj in yaml_obj_read:
            if dict_obj['order'] < 3:
                actors.append(dict_obj['name'])
    except:
        pass
    return actors

# %%
get_actors(df_crew['cast'][8888])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   after removing the cwd from sys.path.
# ['Giulietta Masina', 'Marcello Mastroianni', 'Franco Fabrizi']

# %%
df_crew['Actors'] = df_crew['cast'].apply(get_actors)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   after removing the cwd from sys.path.

# %%
df_crew.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                                           ExPro  \
# 0                      [Ed Catmull, Steve Jobs]
# 1  [Larry J. Franco, Ted Field, Robert W. Cort]
# 2                                            []
# 3                              [Terry McMillan]
# 4                                            []
#
#                                       Directors  \
# 0  [John Lasseter, Roman Figun, Desirée Mourad]
# 1                                [Joe Johnston]
# 2                               [Howard Deutch]
# 3                             [Forest Whitaker]
# 4                               [Charles Shyer]
#
#                                              Writers  \
# 0  [Joss Whedon, Andrew Stanton, Joel Cohen, Alec...
# 1  [Jonathan Hensleigh, Chris van Allsburg, Greg ...
# 2         [Mark Steven Johnson, Mark Steven Johnson]
# 3      [Ronald Bass, Terry McMillan, Terry McMillan]
# 4                     [Nancy Meyers, Albert Hackett]
#
#                                               Actors
# 0                [Tom Hanks, Tim Allen, Don Rickles]
# 1     [Robin Williams, Jonathan Hyde, Kirsten Dunst]
# 2         [Walter Matthau, Jack Lemmon, Ann-Margret]
# 3  [Whitney Houston, Angela Bassett, Loretta Devine]
# 4         [Steve Martin, Diane Keaton, Martin Short]

# %%
df_crew_right = df_crew.iloc[:,2:]

df_crew_right = df_crew_right.rename(columns={'id':'kaggle_id'})

df_crew_right.head()
# Out:
#    kaggle_id                                         ExPro  \
# 0        862                      [Ed Catmull, Steve Jobs]
# 1       8844  [Larry J. Franco, Ted Field, Robert W. Cort]
# 2      15602                                            []
# 3      31357                              [Terry McMillan]
# 4      11862                                            []
#
#                                       Directors  \
# 0  [John Lasseter, Roman Figun, Desirée Mourad]
# 1                                [Joe Johnston]
# 2                               [Howard Deutch]
# 3                             [Forest Whitaker]
# 4                               [Charles Shyer]
#
#                                              Writers  \
# 0  [Joss Whedon, Andrew Stanton, Joel Cohen, Alec...
# 1  [Jonathan Hensleigh, Chris van Allsburg, Greg ...
# 2         [Mark Steven Johnson, Mark Steven Johnson]
# 3      [Ronald Bass, Terry McMillan, Terry McMillan]
# 4                     [Nancy Meyers, Albert Hackett]
#
#                                               Actors
# 0                [Tom Hanks, Tim Allen, Don Rickles]
# 1     [Robin Williams, Jonathan Hyde, Kirsten Dunst]
# 2         [Walter Matthau, Jack Lemmon, Ann-Margret]
# 3  [Whitney Houston, Angela Bassett, Loretta Devine]
# 4         [Steve Martin, Diane Keaton, Martin Short]

# %%
df_crew_right['kaggle_id'] = df_crew_right['kaggle_id'].astype(str)

# %%
df_crew_right.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 6 columns):
# kaggle_id    45476 non-null object
# ExPro        45476 non-null object
# Directors    45476 non-null object
# Writers      45476 non-null object
# Actors       45476 non-null object
# kaggle.id    45476 non-null object
# dtypes: object(6)
# memory usage: 2.1+ MB

# %%
df_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5312 entries, 0 to 45422
# Data columns (total 23 columns):
# adult                5312 non-null bool
# budget               5312 non-null int64
# kaggle_id            5312 non-null object
# imdb_id              5312 non-null object
# original_language    5312 non-null object
# original_title       5312 non-null object
# overview             5302 non-null object
# popularity           5312 non-null object
# date                 5312 non-null datetime64[ns]
# revenue              5312 non-null float64
# runtime              5311 non-null float64
# status               5312 non-null object
# tagline              4587 non-null object
# title                5312 non-null object
# video                5312 non-null object
# vote_avg             5312 non-null float64
# vote_count           5312 non-null float64
# GENRES               5312 non-null object
# COLLECTION           5312 non-null object
# LANGUAGES            5312 non-null object
# PRODUCER             5312 non-null object
# COUNTRIES            5312 non-null object
# kaggle.id            5312 non-null int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(2), object(15)
# memory usage: 959.7+ KB

# %%
df_complete = pd.merge(df_money, df_crew_right, how = 'left', on='kaggle_id')
df_complete.drop(columns=['kaggle.id_x', 'kaggle.id_y'])
# Out:
#       adult     budget kaggle_id    imdb_id original_language  \
# 0      True   30000000       862  tt0114709                en
# 1      True   65000000      8844  tt0113497                en
# 2      True   16000000     31357  tt0114885                en
# 3      True   60000000       949  tt0113277                en
# 4      True   35000000      9091  tt0114576                en
# 5      True   58000000       710  tt0113189                en
# 6      True   62000000      9087  tt0112346                en
# 7      True   44000000     10858  tt0113987                en
# 8      True   98000000      1408  tt0112760                en
# 9      True   52000000       524  tt0112641                en
# 10     True   16500000      4584  tt0114388                en
# 11     True    4000000         5  tt0113101                en
# 12     True   30000000      9273  tt0112281                en
# 13     True   60000000     11517  tt0113845                en
# 14     True   30250000      8012  tt0113161                en
# 15     True   50000000      9691  tt0112401                en
# 16     True    3600000       451  tt0113627                en
# 17     True   12000000      9263  tt0114011                en
# 18     True   18000000       902  tt0112682                fr
# 19     True   29500000        63  tt0114746                en
# 20     True   30000000      9598  tt0112431                en
# 21     True   11000000       687  tt0112818                en
# 22     True   18000000      9312  tt0113855                en
# 23     True   20000000       577  tt0114681                en
# 24     True   10000000     11861  tt0113347                en
# 25     True   33000000       807  tt0114369                en
# 26     True   55000000     10530  tt0114148                en
# 27     True    6000000       629  tt0114814                en
# 28     True   15000000     11448  tt0113819                en
# 29     True    3500000     10634  tt0113118                en
# ...     ...        ...       ...        ...               ...
# 5292   True    3000000     52891  tt1124396                ru
# 5293   True    2500000     69976  tt1620464                ru
# 5294   True    4000000    100791  tt2288121                ru
# 5295   True      82000     43228  tt0050530                en
# 5296   True  152000000    281338  tt3450958                en
# 5297   True   21000000    293768  tt1458169                en
# 5298   True  197471676    339964  tt2239822                en
# 5299   True    7000000    272610  tt3266724                en
# 5300   True    7400000     66526  tt0220656                ta
# 5301   True    2000000     72663  tt1227165                ru
# 5302   True   10000000    326011  tt4187590                ru
# 5303   True    5300000      8453  tt0439662                hi
# 5304   True   30000000    341013  tt2406566                en
# 5305   True  100000000    374720  tt5013056                en
# 5306   True    8500000     14570  tt0089243                en
# 5307   True    8520000    434119  tt5606538                ko
# 5308   True   16000000     10991  tt0235679                ja
# 5309   True   16000000     10991  tt0235679                ja
# 5310   True  260000000    335988  tt3371366                en
# 5311   True    2000000    159447  tt2592500                ru
# 5312   True    2000000     75438  tt1820462                ru
# 5313   True    3000000     57701  tt1820555                ru
# 5314   True    2196531     26147  tt0453365                fi
# 5315   True   60000000    353491  tt1648190                en
# 5316   True   50000000    378236  tt4877122                en
# 5317   True   11000000    395834  tt5362988                en
# 5318   True   12000000     24049  tt0479751                ta
# 5319   True     800000     62757  tt0933361                en
# 5320   True    2000000     63281  tt1718881                en
# 5321   True    5000000     63898  tt1110037                ru
#
#                                    original_title  \
# 0                                       Toy Story
# 1                                         Jumanji
# 2                               Waiting to Exhale
# 3                                            Heat
# 4                                    Sudden Death
# 5                                       GoldenEye
# 6                          The American President
# 7                                           Nixon
# 8                                Cutthroat Island
# 9                                          Casino
# 10                          Sense and Sensibility
# 11                                     Four Rooms
# 12                 Ace Ventura: When Nature Calls
# 13                                    Money Train
# 14                                     Get Shorty
# 15                                      Assassins
# 16                              Leaving Las Vegas
# 17                                   Now and Then
# 18                     La Cité des Enfants Perdus
# 19                                 Twelve Monkeys
# 20                                           Babe
# 21                               Dead Man Walking
# 22                                  Mortal Kombat
# 23                                     To Die For
# 24                  How To Make An American Quilt
# 25                                          Se7en
# 26                                     Pocahontas
# 27                             The Usual Suspects
# 28                               Mighty Aphrodite
# 29                                         Friday
# ...                                           ...
# 5292                                Gitler kaput!
# 5293                               Glukhar v kino
# 5294                       Tot yeshchyo Karloson!
# 5295                     I Was a Teenage Werewolf
# 5296               War for the Planet of the Apes
# 5297                                       Kidnap
# 5298  Valerian and the City of a Thousand Planets
# 5299                                   Black Rose
# 5300                                     முதல்வன்
# 5301                                      Нирвана
# 5302                                    Батальонъ
# 5303                                        Fanaa
# 5304                                Atomic Blonde
# 5305                                      Dunkirk
# 5306                                      Gymkata
# 5307                                           공조
# 5308                         Pokémon 3: The Movie
# 5309                         Pokémon 3: The Movie
# 5310                Transformers: The Last Knight
# 5311                         С новым годом, мамы!
# 5312                                   Beremennyy
# 5313                                 Na Kryuchke!
# 5314                                     FC Venus
# 5315                               The Dark Tower
# 5316                              The Emoji Movie
# 5317                                   Wind River
# 5318                                       சிவாஜி
# 5319                                       Dikari
# 5320                                   Про любоff
# 5321                                     Антидурь
#
#                                                overview  popularity  \
# 0     Led by Woody, Andy's toys live happily in his ...     21.9469
# 1     When siblings Judy and Peter discover an encha...     17.0155
# 2     Cheated on, mistreated and stepped on, the wom...     3.85949
# 3     Obsessive master thief, Neil McCauley leads a ...     17.9249
# 4     International action superstar Jean Claude Van...     5.23158
# 5     James Bond must unmask the mysterious head of ...      14.686
# 6     Widowed U.S. president Andrew Shepherd, one of...     6.31844
# 7     An all-star cast powers this epic look at Amer...       5.092
# 8     Morgan Adams and her slave, William Shaw, are ...     7.28448
# 9     The life of the gambling paradise – Las Vegas ...     10.1374
# 10    Rich Mr. Dashwood dies, leaving his second wif...     10.6732
# 11    It's Ted the Bellhop's first night on the job....     9.02659
# 12    Summoned from an ashram in Tibet, Ace finds hi...     8.20545
# 13    A vengeful New York transit cop decides to ste...     7.33791
# 14    Chili Palmer is a Miami mobster who gets sent ...     12.6696
# 15    Assassin Robert Rath arrives at a funeral to k...     11.0659
# 16    Ben Sanderson, an alcoholic Hollywood screenwr...      10.332
# 17    Waxing nostalgic about the bittersweet passage...     8.68132
# 18    A scientist in a surrealist society kidnaps ch...     9.82242
# 19    In the year 2035, convict James Cole reluctant...     12.2973
# 20    Babe is a little pig who doesn't quite know hi...     14.4048
# 21    A justice drama based on a true story about a ...     6.89132
# 22    For nine generations an evil sorcerer has been...     10.8701
# 23    Susan wants to work in television and will the...     10.4485
# 24    Soon-to-be-wed graduate student Finn Dodd deve...     4.48596
# 25    Two homicide detectives are on a desperate hun...     18.4574
# 26    History comes gloriously to life in Disney's e...     13.2801
# 27    Held in an L.A. interrogation room, Verbal Kin...     16.3025
# 28    When Lenny and his wife, Amanda, adopt a baby,...     15.8991
# 29    Craig and Smokey are two guys in Los Angeles h...     14.5696
# ...                                                 ...         ...
# 5292  A Russian WW2 spy spoof following misadventure...    0.878255
# 5293                                                NaN    0.209434
# 5294  The hero of Mikhail Galustyan, known in our wo...    0.712585
# 5295  A meat-eating teenager (Michael Landon) sees a...     0.75684
# 5296  Caesar and his apes are forced into a deadly c...  146.161786
# 5297  Single mother Karla McCoy lives a perfect life...   20.214579
# 5298  In the 28th century, Valerian and Laureline ar...   15.262706
# 5299  A Russian Police Major is enlisted by the LAPD...    2.482771
# 5300  A man accepts a challenge to act as the Chief ...    0.236466
# 5301  Young Alisa is fed up with her life in Moscow,...    0.679141
# 5302  Russia, 1917, WWI. This is the story of the 1s...    1.557671
# 5303  Zooni Ali Beg (Kajol) is a blind Kashmiri girl...    3.003526
# 5304  An undercover MI6 agent is sent to Berlin duri...   14.455104
# 5305  The miraculous evacuation of Allied soldiers f...   30.938854
# 5306  Johnathan Cabot is a champion gymnast. In the ...    1.542843
# 5307  When a crime organization from North Korea cro...     1.75859
# 5308  When Molly Hale's sadness of her father's disa...    6.480376
# 5309  When Molly Hale's sadness of her father's disa...    6.480376
# 5310  Autobots and Decepticons are at war, with huma...   39.186819
# 5311  A continuation of a famous Russian comedy "Mam...    1.456046
# 5312  The main character of the film Sergey Dobrolyu...    0.397106
# 5313  Rita, a figure skating coach, wants to prevent...    0.445269
# 5314  Pete is a football enthusiast, who plays as a ...    0.947509
# 5315  The last Gunslinger, Roland Deschain, has been...   50.903593
# 5316  Gene, a multi-expressional emoji, sets out on ...   33.694599
# 5317  An FBI agent teams with the town's veteran gam...   40.796775
# 5318  Corrupt police and politicians target a comput...    1.323587
# 5319  The sea, August, interesting and simple people...    0.903061
# 5320  У девушки Даши, приехавшей с подругой «покорят...    0.121844
# 5321  Failing to complete an important assignment wi...    0.039793
#
#            date      revenue  ...  vote_count  \
# 0    1995-10-30  373554033.0  ...      5415.0
# 1    1995-12-15  262797249.0  ...      2413.0
# 2    1995-12-22   81452156.0  ...        34.0
# 3    1995-12-15  187436818.0  ...      1886.0
# 4    1995-12-22   64350171.0  ...       174.0
# 5    1995-11-16  352194034.0  ...      1194.0
# 6    1995-11-17  107879496.0  ...       199.0
# 7    1995-12-22   13681765.0  ...        72.0
# 8    1995-12-22   10017322.0  ...       137.0
# 9    1995-11-22  116112375.0  ...      1343.0
# 10   1995-12-13  135000000.0  ...       364.0
# 11   1995-12-09    4300000.0  ...       539.0
# 12   1995-11-10  212385533.0  ...      1128.0
# 13   1995-11-21   35431113.0  ...       224.0
# 14   1995-10-20  115101622.0  ...       305.0
# 15   1995-10-06   30303072.0  ...       394.0
# 16   1995-10-27   49800000.0  ...       365.0
# 17   1995-10-20   27400000.0  ...        91.0
# 18   1995-05-16    1738611.0  ...       308.0
# 19   1995-12-29  168840000.0  ...      2470.0
# 20   1995-07-18  254134910.0  ...       756.0
# 21   1995-12-29   39363635.0  ...       350.0
# 22   1995-08-18  122195920.0  ...       452.0
# 23   1995-05-20   21284514.0  ...       177.0
# 24   1995-10-06   23574130.0  ...        38.0
# 25   1995-09-22  327311859.0  ...      5915.0
# 26   1995-06-14  346079773.0  ...      1509.0
# 27   1995-07-19   23341568.0  ...      3334.0
# 28   1995-09-13    6700000.0  ...       145.0
# 29   1995-04-26   28215918.0  ...       513.0
# ...         ...          ...  ...         ...
# 5292 2008-09-18    9713500.0  ...         7.0
# 5293 2010-05-06    1477030.0  ...         4.0
# 5294 2012-03-15    9938268.0  ...         6.0
# 5295 1957-06-19    2000000.0  ...        12.0
# 5296 2017-07-11  369907963.0  ...      1675.0
# 5297 2017-08-04   24527158.0  ...       244.0
# 5298 2017-07-20   90024292.0  ...       905.0
# 5299 2014-04-17     855450.0  ...         6.0
# 5300 1999-11-07   22000000.0  ...         6.0
# 5301 2008-07-03     273137.0  ...         5.0
# 5302 2015-02-20    7547762.0  ...         6.0
# 5303 2006-05-26   22175908.0  ...        53.0
# 5304 2017-07-26   90007945.0  ...       748.0
# 5305 2017-07-19  519876949.0  ...      2712.0
# 5306 1985-05-03    5730596.0  ...        14.0
# 5307 2017-01-18   56100000.0  ...         5.0
# 5308 2000-07-08   68411275.0  ...       144.0
# 5309 2000-07-08   68411275.0  ...       144.0
# 5310 2017-06-21  604942143.0  ...      1440.0
# 5311 2012-12-27   11666088.0  ...         9.0
# 5312 2011-07-21    8000000.0  ...         7.0
# 5313 2011-02-03    1957000.0  ...         3.0
# 5314 2005-12-30    2411594.0  ...        10.0
# 5315 2017-08-03   71000000.0  ...       688.0
# 5316 2017-07-28   66913939.0  ...       327.0
# 5317 2017-08-03  184770205.0  ...       181.0
# 5318 2007-06-14   19000000.0  ...        25.0
# 5319 2006-11-23    1328612.0  ...         6.0
# 5320 2010-09-30    1268793.0  ...         3.0
# 5321 2007-09-06    1413000.0  ...         1.0
#
#                                                  GENRES  \
# 0                           [Animation, Comedy, Family]
# 1                          [Adventure, Fantasy, Family]
# 2                              [Comedy, Drama, Romance]
# 3                      [Action, Crime, Drama, Thriller]
# 4                         [Action, Adventure, Thriller]
# 5                         [Adventure, Action, Thriller]
# 6                              [Comedy, Drama, Romance]
# 7                                      [History, Drama]
# 8                                   [Action, Adventure]
# 9                                        [Drama, Crime]
# 10                                     [Drama, Romance]
# 11                                      [Crime, Comedy]
# 12                           [Crime, Comedy, Adventure]
# 13                              [Action, Comedy, Crime]
# 14                            [Comedy, Thriller, Crime]
# 15                 [Action, Adventure, Crime, Thriller]
# 16                                     [Drama, Romance]
# 17                              [Comedy, Drama, Family]
# 18                [Fantasy, Science Fiction, Adventure]
# 19                 [Science Fiction, Thriller, Mystery]
# 20                     [Fantasy, Drama, Comedy, Family]
# 21                                              [Drama]
# 22                                    [Action, Fantasy]
# 23                   [Fantasy, Drama, Comedy, Thriller]
# 24                                     [Drama, Romance]
# 25                           [Crime, Mystery, Thriller]
# 26                [Adventure, Animation, Drama, Family]
# 27                             [Drama, Crime, Thriller]
# 28                                    [Comedy, Romance]
# 29                                             [Comedy]
# ...                                                 ...
# 5292                                           [Comedy]
# 5293                                                 []
# 5294                          [Comedy, Fantasy, Family]
# 5295          [Drama, Fantasy, Horror, Science Fiction]
# 5296                      [Drama, Science Fiction, War]
# 5297                                  [Drama, Thriller]
# 5298               [Adventure, Science Fiction, Action]
# 5299                             [Drama, Crime, Action]
# 5300                                [Foreign, Thriller]
# 5301                                   [Drama, Romance]
# 5302                      [War, Action, Drama, History]
# 5303                 [Action, Drama, Romance, Thriller]
# 5304                                 [Action, Thriller]
# 5305            [Action, Drama, History, Thriller, War]
# 5306                                    [Action, Drama]
# 5307                            [Action, Drama, Comedy]
# 5308    [Adventure, Fantasy, Animation, Action, Family]
# 5309    [Adventure, Fantasy, Animation, Action, Family]
# 5310     [Action, Science Fiction, Thriller, Adventure]
# 5311                                    [Comedy, Drama]
# 5312                                           [Comedy]
# 5313                                  [Comedy, Romance]
# 5314                                  [Comedy, Romance]
# 5315  [Action, Western, Science Fiction, Fantasy, Ho...
# 5316                        [Comedy, Family, Animation]
# 5317                 [Action, Crime, Mystery, Thriller]
# 5318                            [Action, Comedy, Drama]
# 5319                                    [Comedy, Drama]
# 5320                                   [Romance, Drama]
# 5321                   [Action, Comedy, Crime, Foreign]
#
#                                   COLLECTION  \
# 0                       Toy Story Collection
# 1
# 2
# 3
# 4
# 5                      James Bond Collection
# 6
# 7
# 8
# 9
# 10
# 11
# 12                    Ace Ventura Collection
# 13
# 14                   Chili Palmer Collection
# 15
# 16
# 17
# 18
# 19
# 20                           Babe Collection
# 21
# 22                  Mortal Kombat Collection
# 23
# 24
# 25
# 26                     Pocahontas Collection
# 27
# 28
# 29                         Friday Collection
# ...                                      ...
# 5292
# 5293
# 5294
# 5295
# 5296  Planet of the Apes (Reboot) Collection
# 5297
# 5298
# 5299
# 5300
# 5301
# 5302
# 5303
# 5304
# 5305
# 5306
# 5307
# 5308                      Pokémon Collection
# 5309                      Pokémon Collection
# 5310                 Transformers Collection
# 5311                      Mommies Collection
# 5312
# 5313
# 5314
# 5315
# 5316
# 5317
# 5318
# 5319
# 5320
# 5321
#
#                                  LANGUAGES  \
# 0                                [English]
# 1                      [English, Français]
# 2                                [English]
# 3                       [English, Español]
# 4                                [English]
# 5              [English, Pусский, Español]
# 6                                [English]
# 7                                [English]
# 8                         [English, Latin]
# 9                                [English]
# 10                               [English]
# 11                               [English]
# 12                               [English]
# 13                               [English]
# 14                               [English]
# 15          [English, Español, Nederlands]
# 16                               [English]
# 17                               [English]
# 18                   [广州话 / 廣州話, Français]
# 19                     [English, Français]
# 20                               [English]
# 21                               [English]
# 22                               [English]
# 23                               [English]
# 24                               [English]
# 25                               [English]
# 26                               [English]
# 27    [Español, English, Français, Magyar]
# 28                               [English]
# 29                               [English]
# ...                                    ...
# 5292                     [Polski, Pусский]
# 5293                             [Pусский]
# 5294                             [Pусский]
# 5295                             [English]
# 5296                             [English]
# 5297                             [English]
# 5298                   [Français, English]
# 5299                    [English, Pусский]
# 5300                               [தமிழ்]
# 5301                             [Pусский]
# 5302                             [Pусский]
# 5303              [हिन्दी, Italiano, اردو]
# 5304  [svenska, English, Deutsch, Pусский]
# 5305          [English, Français, Deutsch]
# 5306                             [English]
# 5307                             [한국어/조선말]
# 5308                             [English]
# 5309                             [English]
# 5310                             [English]
# 5311                             [Pусский]
# 5312                             [Pусский]
# 5313                             [Pусский]
# 5314                               [suomi]
# 5315                             [English]
# 5316                             [English]
# 5317                             [English]
# 5318                       [தமிழ், తెలుగు]
# 5319                             [Pусский]
# 5320                             [Pусский]
# 5321                             [Pусский]
#
#                                                PRODUCER  \
# 0                             [Pixar Animation Studios]
# 1     [TriStar Pictures, Teitler Film, Interscope Co...
# 2              [Twentieth Century Fox Film Corporation]
# 3     [Regency Enterprises, Forward Pass, Warner Bros.]
# 4     [Universal Pictures, Imperial Entertainment, S...
# 5                     [United Artists, Eon Productions]
# 6        [Columbia Pictures, Castle Rock Entertainment]
# 7     [Hollywood Pictures, Cinergi Pictures Entertai...
# 8     [Le Studio Canal+, Laurence Mark Productions, ...
# 9     [Universal Pictures, Légende Entreprises, Syal...
# 10    [Columbia Pictures Corporation, Mirage Enterpr...
# 11                        [Miramax Films, A Band Apart]
# 12    [O Entertainment, Warner Bros., Morgan Creek P...
# 13                                  [Columbia Pictures]
# 14            [Jersey Films, Metro-Goldwyn-Mayer (MGM)]
# 15    [Silver Pictures, Canal+, Warner Bros., Dino D...
# 16                 [United Artists, Intial Productions]
# 17                                    [New Line Cinema]
# 18    [Procirep, Constellation Productions, France 3...
# 19    [Universal Pictures, Atlas Entertainment, Clas...
# 20     [Universal Pictures, Kennedy Miller Productions]
# 21    [Havoc, PolyGram Filmed Entertainment, Working...
# 22           [New Line Cinema, Threshold Entertainment]
# 23    [The Rank Organisation, Columbia Pictures Corp...
# 24           [Universal Pictures, Amblin Entertainment]
# 25    [New Line Cinema, Juno Pix, Cecchi Gori Pictures]
# 26    [Walt Disney Pictures, Walt Disney Feature Ani...
# 27    [Blue Parrot Productions, Bad Hat Harry Produc...
# 28                   [Miramax Films, Magnolia Pictures]
# 29                                    [New Line Cinema]
# ...                                                 ...
# 5292                                         [Leopolis]
# 5293                                                 []
# 5294                                     [Enjoy Movies]
# 5295                               [Sunset Productions]
# 5296                            [Chernin Entertainment]
# 5297  [Ingenious Media, Di Bonaventura Pictures, Gol...
# 5298                                       [EuropaCorp]
# 5299                   [Hollywood Storm, Czar Pictures]
# 5300                                       [S Pictures]
# 5301                                                 []
# 5302                 [Art Pictures Studio, Corner Work]
# 5303                                   [Yash Raj Films]
# 5304  [Denver and Delilah Productions, Film i Väst, ...
# 5305  [Canal+, Studio Canal, Warner Bros., Syncopy, ...
# 5306                        [Metro-Goldwyn-Mayer (MGM)]
# 5307                                 [CJ Entertainment]
# 5308  [TV Tokyo, 4 Kids Entertainment, Nintendo, Pik...
# 5309  [TV Tokyo, 4 Kids Entertainment, Nintendo, Pik...
# 5310  [Paramount Pictures, Di Bonaventura Pictures, ...
# 5311                                     [Enjoy Movies]
# 5312                                                 []
# 5313                                           [Profit]
# 5314                                     [Talent House]
# 5315  [Imagine Entertainment, Weed Road Pictures, Me...
# 5316       [Columbia Pictures, Sony Pictures Animation]
# 5317  [Thunder Road Pictures, Star Thrower Entertain...
# 5318                                  [AVM Productions]
# 5319                                                 []
# 5320                                           [Profit]
# 5321                                                 []
#
#                                               COUNTRIES  \
# 0                            [United States of America]
# 1                            [United States of America]
# 2                            [United States of America]
# 3                            [United States of America]
# 4                            [United States of America]
# 5            [United Kingdom, United States of America]
# 6                            [United States of America]
# 7                            [United States of America]
# 8     [France, Germany, Italy, United States of Amer...
# 9                    [France, United States of America]
# 10           [United Kingdom, United States of America]
# 11                           [United States of America]
# 12                           [United States of America]
# 13                           [United States of America]
# 14                           [United States of America]
# 15                   [France, United States of America]
# 16                           [United States of America]
# 17                           [United States of America]
# 18                             [France, Germany, Spain]
# 19                           [United States of America]
# 20                [Australia, United States of America]
# 21           [United States of America, United Kingdom]
# 22                           [United States of America]
# 23                           [United States of America]
# 24                           [United States of America]
# 25                           [United States of America]
# 26                           [United States of America]
# 27                           [United States of America]
# 28                           [United States of America]
# 29                           [United States of America]
# ...                                                 ...
# 5292                                  [Ukraine, Russia]
# 5293                                           [Russia]
# 5294                                           [Russia]
# 5295                         [United States of America]
# 5296                 [Canada, United States of America]
# 5297         [United Kingdom, United States of America]
# 5298                                           [France]
# 5299                                           [Russia]
# 5300                                            [India]
# 5301                                           [Russia]
# 5302                                           [Russia]
# 5303                                            [India]
# 5304        [Sweden, United States of America, Germany]
# 5305  [Netherlands, France, United Kingdom, United S...
# 5306                  [United States of America, Japan]
# 5307                                      [South Korea]
# 5308                                            [Japan]
# 5309                                            [Japan]
# 5310                         [United States of America]
# 5311                                           [Russia]
# 5312                                           [Russia]
# 5313                                           [Russia]
# 5314                                          [Finland]
# 5315           [South Africa, United States of America]
# 5316                         [United States of America]
# 5317  [United Kingdom, United States of America, Can...
# 5318                                            [India]
# 5319                                                 []
# 5320                                           [Russia]
# 5321                                           [Russia]
#
#                                                   ExPro  \
# 0                              [Ed Catmull, Steve Jobs]
# 1          [Larry J. Franco, Ted Field, Robert W. Cort]
# 2                                      [Terry McMillan]
# 3                    [Pieter Jan Brugge, Arnon Milchan]
# 4                                                    []
# 5                                         [Tom Pevsner]
# 6                                                    []
# 7                                                    []
# 8                                        [Mario Kassar]
# 9                                                    []
# 10                                     [Sydney Pollack]
# 11              [Quentin Tarantino, Alexandre Rockwell]
# 12                                        [Gary Barber]
# 13     [Tracy Barone, Adam Fields, Frederick S. Pierce]
# 14                                                   []
# 15           [Lauren Shuler Donner, Dino De Laurentiis]
# 16                    [Stuart Reynolds , Paige Simpson]
# 17                                      [Jennifer Todd]
# 18                                                   []
# 19     [Robert Cavallo, Gary Levinsohn, Robert Kosberg]
# 20                                                   []
# 21                            [Tim Bevan, Eric Fellner]
# 22                       [Robert Engelman, Danny Simon]
# 23       [Jonathan T. Taplin, Joseph M. Caracciolo Jr.]
# 24    [Walter F. Parkes, Deborah Jelin Newmyer, Laur...
# 25         [Gianni Nunnari, Dan Kolsrud, Anne Kopelson]
# 26                                                   []
# 27    [Robert Jones, Art Horan, François Duplat, Han...
# 28                     [Jean Doumanian, J.E. Beaucaire]
# 29                                                   []
# ...                                                 ...
# 5292                                                 []
# 5293                                                 []
# 5294                                                 []
# 5295                                                 []
# 5296                                                 []
# 5297  [Colin Bates, Bill Johnson, David Dinerstein, ...
# 5298                                                 []
# 5299                                                 []
# 5300                                                 []
# 5301                                                 []
# 5302                                                 []
# 5303                                                 []
# 5304  [Nick Meyer, Fredrik Zander, David Guillod, Ku...
# 5305                       [Jake Myers, Greg Silverman]
# 5306                                                 []
# 5307                                                 []
# 5308                                                 []
# 5309                                                 []
# 5310                       [Michael Bay, Brian Goldner]
# 5311                                                 []
# 5312                                                 []
# 5313                                                 []
# 5314                                                 []
# 5315  [Anders Thomas Jensen, G. Mac Brown, Erica Hug...
# 5316                                     [Ben Waisbren]
# 5317                                                 []
# 5318                                                 []
# 5319                                                 []
# 5320                                  [Vera Vilenskaya]
# 5321                                                 []
#
#                                               Directors  \
# 0          [John Lasseter, Roman Figun, Desirée Mourad]
# 1                                        [Joe Johnston]
# 2                                     [Forest Whitaker]
# 3          [Michael Mann, Cate Hardman, Michael Waxman]
# 4                                         [Peter Hyams]
# 5                       [Martin Campbell, June Randall]
# 6                                          [Rob Reiner]
# 7                                        [Oliver Stone]
# 8                                        [Renny Harlin]
# 9                                     [Martin Scorsese]
# 10                                            [Ang Lee]
# 11    [Allison Anders, Alexandre Rockwell, Robert Ro...
# 12                                     [Steve Oedekerk]
# 13                      [Joseph Ruben, Corey B. Yugler]
# 14                                   [Barry Sonnenfeld]
# 15                                     [Richard Donner]
# 16                                        [Mike Figgis]
# 17                                [Lesli Linka Glatter]
# 18                      [Jean-Pierre Jeunet, Marc Caro]
# 19    [Terry Gilliam, Marilyn Bailey, Mark Egerton, ...
# 20                                       [Chris Noonan]
# 21    [Tim Robbins, Allan F. Nicholls, Sam Hoffman, ...
# 22                  [Paul W.S. Anderson, Jules Stewart]
# 23                                       [Gus Van Sant]
# 24                                  [Jocelyn Moorhouse]
# 25                                      [David Fincher]
# 26    [Mike Gabriel, Eric Goldberg, Rick Moore, Pete...
# 27           [Bryan Singer, Wendy Dallas, Haley McLane]
# 28                            [Woody Allen, Kay Chapin]
# 29                                       [F. Gary Gray]
# ...                                                 ...
# 5292                                 [Marius Balchunas]
# 5293                                                 []
# 5294                                 [Sarik Andreasyan]
# 5295                   [Gene Fowler Jr., Jack R. Berne]
# 5296                                      [Matt Reeves]
# 5297    [Luis Prieto, Nicole Garcea, Alexander B. Hill]
# 5298  [Luc Besson, Louise Molière, Charles Jodoin-Ke...
# 5299                                 [Alexander Nevsky]
# 5300                              [S. Shankar, Hosimin]
# 5301                                    [Igor Voloshin]
# 5302                                 [Dmitri Meskhiyev]
# 5303                                      [Kunal Kohli]
# 5304  [David Leitch, Susie Jones, Gabriella Winkler,...
# 5305  [Christopher Nolan, Steve Gehrke, Alina Gatti,...
# 5306                                    [Robert Clouse]
# 5307                                    [Sung-hoon Kim]
# 5308                 [Michael Haigney, Kunihiko Yuyama]
# 5309                 [Michael Haigney, Kunihiko Yuyama]
# 5310                                      [Michael Bay]
# 5311  [Sarik Andreasyan, Artyom Aksyonenko, Anton Bo...
# 5312                                 [Sarik Andreasyan]
# 5313                               [Natalya Uglitskikh]
# 5314                                       [Joona Tena]
# 5315  [Nikolaj Arcel, David H. Venghaus Jr., Morag C...
# 5316                                  [Anthony Leondis]
# 5317                                  [Taylor Sheridan]
# 5318                                       [S. Shankar]
# 5319                                  [Viktor Shamirov]
# 5320                                   [Olga Subbotina]
# 5321                             [Vladimir Shchegolkov]
#
#                                                 Writers  \
# 0     [Joss Whedon, Andrew Stanton, Joel Cohen, Alec...
# 1     [Jonathan Hensleigh, Chris van Allsburg, Greg ...
# 2         [Ronald Bass, Terry McMillan, Terry McMillan]
# 3                                        [Michael Mann]
# 4                  [Karen Elise Baldwin, Gene Quintano]
# 5     [Ian Fleming, Jeffrey Caine, Bruce Feirstein, ...
# 6                                        [Aaron Sorkin]
# 7                     [Oliver Stone, Stephen J. Rivele]
# 8     [James Gorman, Michael Frost Beckner, Marc Nor...
# 9     [Martin Scorsese, Nicholas Pileggi, Nicholas P...
# 10                         [Jane Austen, Emma Thompson]
# 11    [Allison Anders, Alexandre Rockwell, Robert Ro...
# 12                     [Jack Bernstein, Steve Oedekerk]
# 13                                    [Doug Richardson]
# 14                        [Elmore Leonard, Scott Frank]
# 15    [Lilly Wachowski, Lana Wachowski, Lilly Wachow...
# 16                          [Mike Figgis, John O'Brien]
# 17                                    [I. Marlene King]
# 18       [Jean-Pierre Jeunet, Marc Caro, Gilles Adrien]
# 19                  [David Webb Peoples, Janet Peoples]
# 20       [George Miller, Dick King-Smith, Chris Noonan]
# 21            [Tim Robbins, Helen Prejean, Brick Mason]
# 22                 [Ed Boon, John Tobias, Kevin Droney]
# 23                          [Joyce Maynard, Buck Henry]
# 24                        [Jane Anderson, Whitney Otto]
# 25                                [Andrew Kevin Walker]
# 26    [Susannah Grant, Philip LaZebnik, Chris Buck, ...
# 27                  [Christopher McQuarrie, John Coven]
# 28                                        [Woody Allen]
# 29                                  [DJ Pooh, Ice Cube]
# ...                                                 ...
# 5292                                 [Marius Balchunas]
# 5293                                                 []
# 5294               [Sarik Andreasyan, Pavel Karnaukhov]
# 5295  [Herman Cohen, Herman Cohen, Aben Kandel, Aben...
# 5296         [Pierre Boulle, Mark Bomback, Matt Reeves]
# 5297                                   [Knate Gwaltney]
# 5298  [Luc Besson, Pierre Christin, Jean-Claude Mézi...
# 5299                      [Brent Huff, George Saunders]
# 5300       [Sujatha Rangarajan, S. Shankar, S. Shankar]
# 5301                                                 []
# 5302  [Igor Ugolnikov, Dmitri Meskhiyev, Yevgeny Ayz...
# 5303                                  [Shibani Bathija]
# 5304      [Kurt Johnstad, Antony Johnston, Todd Harris]
# 5305                                [Christopher Nolan]
# 5306                            [Charles Robert Carner]
# 5307                                    [Yoon Hyeon-ho]
# 5308                   [Kunihiko Yuyama, Takeshi Shudo]
# 5309                   [Kunihiko Yuyama, Takeshi Shudo]
# 5310  [Akiva Goldsman, Steven S. DeKnight, Robert Ki...
# 5311                  [Sarik Andreasyan, Olga Antonova]
# 5312                                 [Sarik Andreasyan]
# 5313               [Vitaly Moskalenko, Yelena Raiskaya]
# 5314                                                 []
# 5315  [Anders Thomas Jensen, Stephen King, Akiva Gol...
# 5316                                  [Anthony Leondis]
# 5317                                  [Taylor Sheridan]
# 5318       [S. Shankar, S. Shankar, Sujatha Rangarajan]
# 5319                                  [Viktor Shamirov]
# 5320                  [Victoria Evseeva, Oksana Robski]
# 5321                                                 []
#
#                                                  Actors
# 0                   [Tom Hanks, Tim Allen, Don Rickles]
# 1        [Robin Williams, Jonathan Hyde, Kirsten Dunst]
# 2     [Whitney Houston, Angela Bassett, Loretta Devine]
# 3               [Al Pacino, Robert De Niro, Val Kilmer]
# 4     [Jean-Claude Van Damme, Powers Boothe, Dorian ...
# 5        [Pierce Brosnan, Sean Bean, Izabella Scorupco]
# 6     [Michael Douglas, Annette Bening, Michael J. Fox]
# 7          [Anthony Hopkins, Joan Allen, Powers Boothe]
# 8         [Geena Davis, Matthew Modine, Frank Langella]
# 9             [Robert De Niro, Sharon Stone, Joe Pesci]
# 10            [Kate Winslet, Emma Thompson, Hugh Grant]
# 11         [Tim Roth, Antonio Banderas, Jennifer Beals]
# 12              [Jim Carrey, Ian McNeice, Simon Callow]
# 13     [Wesley Snipes, Woody Harrelson, Jennifer Lopez]
# 14            [John Travolta, Gene Hackman, Rene Russo]
# 15    [Sylvester Stallone, Antonio Banderas, Juliann...
# 16         [Nicolas Cage, Elisabeth Shue, Julian Sands]
# 17      [Christina Ricci, Rosie O'Donnell, Thora Birch]
# 18        [Ron Perlman, Dominique Pinon, Judith Vittet]
# 19           [Bruce Willis, Madeleine Stowe, Brad Pitt]
# 20    [Christine Cavanaugh, Miriam Margolyes, Danny ...
# 21           [Susan Sarandon, Sean Penn, Robert Prosky]
# 22      [Christopher Lambert, Robin Shou, Linden Ashby]
# 23        [Nicole Kidman, Matt Dillon, Joaquin Phoenix]
# 24         [Winona Ryder, Anne Bancroft, Ellen Burstyn]
# 25         [Brad Pitt, Morgan Freeman, Gwyneth Paltrow]
# 26       [Irene Bedard, Mel Gibson, David Ogden Stiers]
# 27    [Stephen Baldwin, Gabriel Byrne, Chazz Palmint...
# 28    [Woody Allen, Mira Sorvino, Helena Bonham Carter]
# 29                   [Ice Cube, Chris Tucker, Nia Long]
# ...                                                 ...
# 5292  [Pavel Derevyanko, Anna Semenovich, Yuriy Galt...
# 5293                                                 []
# 5294   [Mikhail Galustyan, Igor Vernik, Mariya Semkina]
# 5295   [Michael Landon, Yvonne Fedderson, Whit Bissell]
# 5296         [Andy Serkis, Woody Harrelson, Steve Zahn]
# 5297           [Halle Berry, Sage Correa, Chris McGinn]
# 5298         [Dane DeHaan, Cara Delevingne, Clive Owen]
# 5299   [Alexander Nevsky, Kristanna Loken, Adrian Paul]
# 5300         [Arjun Sarja, Manisha Koirala, Raghuvaran]
# 5301  [Olga Sutulova, Mariya Shalayeva, Artur Smolya...
# 5302  [Mariya Aronova, Mariya Kozhevnikova, Irina Ra...
# 5303                  [Kajol, Aamir Khan, Rishi Kapoor]
# 5304    [Charlize Theron, James McAvoy, Sofia Boutella]
# 5305   [Fionn Whitehead, Tom Glynn-Carney, Jack Lowden]
# 5306    [Kurt Thomas, Tetchie Agbayani, Richard Norton]
# 5307              [Hyun Bin, Yoo Hae-jin, Kim Joo-hyuk]
# 5308                  [Veronica Taylor, Rachael Lillis]
# 5309                  [Veronica Taylor, Rachael Lillis]
# 5310       [Mark Wahlberg, Josh Duhamel, Laura Haddock]
# 5311  [Alain Delon, Elizaveta Boyarskaya, Agniya Dit...
# 5312  [Dmitriy Dyuzhev, Mikhail Galustyan, Ville Haa...
# 5313  [Ekaterina Vilkova, Konstantin Kryukov, Marat ...
# 5314  [Minna Haapkylä, Petteri Summanen, Laura Malmi...
# 5315      [Idris Elba, Matthew McConaughey, Tom Taylor]
# 5316            [T.J. Miller, James Corden, Anna Faris]
# 5317   [Jeremy Renner, Elizabeth Olsen, Gil Birmingham]
# 5318                 [Rajinikanth, Suman, Shriya Saran]
# 5319  [Marat Basharov, Yuriy Kutsenko, Vladislav Gal...
# 5320  [Fyodor Bondarchuk, Oksana Fandera, Juozas Bud...
# 5321  [Vladimir Turchinsky, Dmitriy Dyuzhev, Tatyana...
#
# [5322 rows x 26 columns]

# %%
#Exporting completed dataframe to dir data/temp/movie_complete_df, making sure that the file is compressed to save memory
df_complete.to_csv('data/temp/movie_complete_df', index=False, compression='gzip')
